# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\archive (2)\Heart_Disease_Prediction.csv")

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 0                          3         3      Presence
# 1                          0         7       Absence
# 2                          0         7      Presence
# 3                          1         7       Absence
# 4                          1         3       Absence
# ..                       ...       ...           ...
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence
#
# [270 rows x 14 columns]

# %%
df[df["Heart Disease"]=='Presence']['Heart Disease']=0
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9320\1717060805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df["Heart Disease"]=='Presence']['Heart Disease']=0

# %%
df[df["Heart Disease"]=='Absence']['Heart Disease']=1
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9320\2443049358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df["Heart Disease"]=='Absence']['Heart Disease']=1

# %%
df.loc[df['Heart Disease'] == 'Presence','Heart Disease'] = 0

# %%
df.loc[df["Heart Disease"] == 'Absence','Heart Disease'] = 1

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3             0
# 1                        0         7             1
# 2                        0         7             0
# 3                        1         7             1
# 4                        1         3             1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Heart Disease']= le.fit_transform(df["Heart Disease"])

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              0
# 1                        0         7              1
# 2                        0         7              0
# 3                        1         7              1
# 4                        1         3              1

# %%
corr=df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr,annot=True)
plt.show()

# %%
df.drop('FBS over 120',axis=1,inplace=True)

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  EKG results  Max HR  \
# 0     70    1                4  130          322            2     109
# 1     67    0                3  115          564            2     160
# 2     57    1                2  124          261            0     141
# 3     64    1                4  128          263            0     105
# 4     74    0                2  120          269            2     121
# ..   ...  ...              ...  ...          ...          ...     ...
# 265   52    1                3  172          199            0     162
# 266   44    1                2  120          263            0     173
# 267   56    0                2  140          294            2     153
# 268   57    1                4  140          192            0     148
# 269   67    1                4  160          286            2     108
#
#      Exercise angina  ST depression  Slope of ST  Number of vessels fluro  \
# 0                  0            2.4            2                        3
# 1                  0            1.6            2                        0
# 2                  0            0.3            1                        0
# 3                  1            0.2            2                        1
# 4                  1            0.2            1                        1
# ..               ...            ...          ...                      ...
# 265                0            0.5            1                        0
# 266                0            0.0            1                        0
# 267                0            1.3            2                        0
# 268                0            0.4            2                        0
# 269                1            1.5            2                        3
#
#      Thallium  Heart Disease
# 0           3              0
# 1           7              1
# 2           7              0
# 3           7              1
# 4           3              1
# ..        ...            ...
# 265         7              1
# 266         7              1
# 267         3              1
# 268         6              1
# 269         3              0
#
# [270 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Heart Disease',axis=1)

# %%
X
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  EKG results  Max HR  \
# 0     70    1                4  130          322            2     109
# 1     67    0                3  115          564            2     160
# 2     57    1                2  124          261            0     141
# 3     64    1                4  128          263            0     105
# 4     74    0                2  120          269            2     121
# ..   ...  ...              ...  ...          ...          ...     ...
# 265   52    1                3  172          199            0     162
# 266   44    1                2  120          263            0     173
# 267   56    0                2  140          294            2     153
# 268   57    1                4  140          192            0     148
# 269   67    1                4  160          286            2     108
#
#      Exercise angina  ST depression  Slope of ST  Number of vessels fluro  \
# 0                  0            2.4            2                        3
# 1                  0            1.6            2                        0
# 2                  0            0.3            1                        0
# 3                  1            0.2            2                        1
# 4                  1            0.2            1                        1
# ..               ...            ...          ...                      ...
# 265                0            0.5            1                        0
# 266                0            0.0            1                        0
# 267                0            1.3            2                        0
# 268                0            0.4            2                        0
# 269                1            1.5            2                        3
#
#      Thallium
# 0           3
# 1           7
# 2           7
# 3           7
# 4           3
# ..        ...
# 265         7
# 266         7
# 267         3
# 268         6
# 269         3
#
# [270 rows x 12 columns]

# %%
y =df['Heart Disease']

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 265    1
# 266    1
# 267    1
# 268    1
# 269    0
# Name: Heart Disease, Length: 270, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=24)

# %%
X_train
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  EKG results  Max HR  \
# 249   60    1                4  145          282            2     142
# 112   60    0                4  158          305            2     161
# 87    59    1                1  178          270            2     145
# 124   54    1                3  125          273            2     152
# 82    58    1                4  150          270            2     111
# ..   ...  ...              ...  ...          ...          ...     ...
# 207   58    1                3  105          240            2     154
# 123   65    0                3  160          360            2     151
# 129   60    1                4  117          230            0     160
# 145   53    1                4  123          282            0      95
# 192   54    1                2  108          309            0     156
#
#      Exercise angina  ST depression  Slope of ST  Number of vessels fluro  \
# 249                1            2.8            2                        2
# 112                0            0.0            1                        0
# 87                 0            4.2            3                        0
# 124                0            0.5            3                        1
# 82                 1            0.8            1                        0
# ..               ...            ...          ...                      ...
# 207                1            0.6            2                        0
# 123                0            0.8            1                        0
# 129                1            1.4            1                        2
# 145                1            2.0            2                        2
# 192                0            0.0            1                        0
#
#      Thallium
# 249         7
# 112         3
# 87          7
# 124         3
# 82          7
# ..        ...
# 207         7
# 123         3
# 129         7
# 145         7
# 192         7
#
# [216 rows x 12 columns]

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=2000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
y_pred =model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7777777777777778

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[15  8]
#  [ 4 27]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.65      0.71        23
#            1       0.77      0.87      0.82        31
#
#     accuracy                           0.78        54
#    macro avg       0.78      0.76      0.77        54
# weighted avg       0.78      0.78      0.77        54

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7777777777777778

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6111111111111112

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7407407407407407

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7777777777777778

# %%
from sklearn.svm import SVC

model = SVC(kernel='rbf')
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6851851851851852

# %%
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8148148148148148

# %%
models = {
    "Logistic": LogisticRegression(max_iter=1000),
    "KNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC(),
    "GradientBoostingClassifier": GradientBoostingClassifier()
}

for name, model in models.items():
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    print(name, "Accuracy:", accuracy_score(y_test, pred))
# Out:
# Logistic Accuracy: 0.7777777777777778
# KNN Accuracy: 0.6111111111111112
# Decision Tree Accuracy: 0.7592592592592593
# Random Forest Accuracy: 0.7777777777777778
# SVM Accuracy: 0.6851851851851852
# GradientBoostingClassifier Accuracy: 0.8148148148148148
